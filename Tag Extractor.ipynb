# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from sklearn.feature_extraction import text
import tldextract
from matplotlib import pyplot as plt

# %%
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('history.csv', parse_dates = True)
df = df.drop(['id','lastVisitTime', 'lastVisitTimeTimestamp', 'typedCount', 'visitCount'], axis = 1)

# %%
# Extract domains from URL
domains = df.url.apply(lambda x: tldextract.extract(x).domain)
df = pd.concat([df, domains.rename('domains')], axis = 1)

def f(x):
    t = str(x.title).lower().strip()
    if t != x.domains:
        x.title = t.replace(x.domains, "")
    if x.title == 'nan':
        x.title = x.domains
    return x

df = df.apply(f, axis = 1)

# %%
# Define Stop Words
my_stop_words = text.ENGLISH_STOP_WORDS.union(["suche", "search"])
cv = CountVectorizer(stop_words=my_stop_words)

# %%
# Get Distance between tags: Number of docs where they occur together

def freq_matrix(df):
    # Get matrix representation of CountVectorizer
    X = cv.fit_transform(df[~(pd.isnull(df.title))].title)
    X = X.toarray()
    X = pd.DataFrame(X)
    feature_names = list(np.array(cv.get_feature_names()))
    X.columns = feature_names
    return X

freq_matrix = freq_matrix(df)

def distance(w1, w2):
    return np.inner(freq_matrix[w1], freq_matrix[w2])

# Returns a dataframe (shape = (len(word_array), 1)) containing neighbors of each word in word_array

def get_neighbors(word_array):
    neighbors = pd.DataFrame(index = word_array, columns = ["neighbors"])
    for w in word_array:
        w_neighbors = {}
        for v in word_array:
            if v != w and distance(w,v) > 0:
                w_neighbors[v] = distance(w,v)
        neighbors.loc[w, "neighbors"] = [{k: v} for k, v in sorted(w_neighbors.items(), key=lambda item: item[1], reverse = True)]
    return neighbors

# %%
# Get tags
def get_tags(array):
    X = cv.fit_transform(array)
    feature_names = list(np.array(cv.get_feature_names()))
    freq_word = list(np.sum(X.toarray(), axis = 0))
    freq_count = {feature_names[i]: freq_word[i] for i in range(0, len(feature_names))}
    freq_count = pd.DataFrame([[k,v] for k, v in sorted(freq_count.items(), key=lambda item: item[1], reverse = True)])
    freq_count.columns = ["Tag", "Frequency"]
    return freq_count

# %%
# Filter rows

my_filter = ["google"]

def filter_rows(df, my_filter, gate):
        
    def check(row,my_filter, gate):
        if gate == "And":
            for f in my_filter:
                if f not in str(row.title).lower():
                    return False
            return True
        else:
            for f in my_filter:
                if f in str(row.title).lower():
                    return True
            return False
            
            

    filtered_rows = df[df.apply(lambda x: check(x, my_filter, gate), axis = 1)]
    filtered_rows = filtered_rows[~pd.isnull(filtered_rows.title)]
    
    return filtered_rows

# %%
Neighbors = get_neighbors(list(get_tags(filter_rows(df, [""], "And").title).head(200).Tag))

# %%
print(Neighbors.loc["machine", "neighbors"])
# Out:
# [{'learning': 339}, {'titanic': 66}, {'data': 50}, {'jobs': 44}, {'mathematics': 27}, {'opencourseware': 25}, {'home': 23}, {'neural': 21}, {'analysis': 21}, {'science': 19}, {'google': 18}, {'new': 13}, {'chrome': 12}, {'ai': 11}, {'stack': 10}, {'india': 10}, {'video': 10}, {'10': 10}, {'python': 9}, {'university': 9}, {'com': 9}, {'overflow': 8}, {'learn': 7}, {'discussions': 6}, {'master': 6}, {'course': 6}, {'online': 5}, {'regression': 5}, {'web': 4}, {'linear': 4}, {'courses': 3}, {'store': 3}, {'networks': 2}, {'ashoka': 2}, {'algorithms': 2}, {'exchange': 2}, {'best': 2}, {'computer': 2}, {'algebra': 2}, {'logistic': 2}, {'using': 2}, {'stanford': 1}, {'documentation': 1}, {'deeplearning': 1}, {'deep': 1}, {'kshitij': 1}, {'kapoor': 1}, {'test': 1}, {'mail': 1}, {'2020': 1}, {'string': 1}, {'alumni': 1}, {'edu': 1}, {'algorithm': 1}, {'cross': 1}]

# %%
filter_rows(df, ["pandas", "regression"], gate = "or")
# Out:
#                                                   title  \
# 137   learn python, data viz, pandas & more | tutori...
# 509   pandas.dataframe.sample — pandas 1.0.4 documen...
# 510                             .random pandas - -suche
# 629   pandas.dataframe.aggregate — pandas 1.0.4 docu...
# 635   pandas.dataframe.mode — pandas 1.0.4 documenta...
# 651   pandas.dataframe.mode — pandas 1.0.4 documenta...
# 652   pandas.dataframe.aggregate — pandas 1.0.4 docu...
# 653                           aggregate pandas - -suche
# 654                               .mode pandas - -suche
# 655          pandas.concat — pandas 1.0.4 documentation
# 656                              pandas concat - -suche
# 657       pandas.factorize — pandas 1.0.4 documentation
# 658   merge, join, and concatenate — pandas 1.0.4 do...
# 659               concatenate on column pandas - -suche
# 660                              concat pandas - -suche
# 661       pandas.dataframe — pandas 1.0.4 documentation
# 691   python - pandas: convert categories to numbers...
# 692   convert string levels to interger levels categ...
# 768   python pandas dataframe: replace variable by t...
# 769   python pandas dataframe: replace variable by t...
# 770   python - change values in pandas dataframe acc...
# 771   python - change values in pandas dataframe acc...
# 779                              concat pandas - -suche
# 780   replace value with its frequency in pandas - -...
# 787   group by: split-apply-combine — pandas 1.0.4 d...
# 824   pandas - custom transformer that splits dates ...
# 843               chi square test pandas - google-suche
# 845   python - correlation among multiple categorica...
# 851   julie michelman - pandas, pipelines, and custo...
# 881                     chi square test pandas - -suche
# 883   python - correlation among multiple categorica...
# 884   include categorical variables in corrplot pand...
# 889   how to find the correlation between two pandas...
# 890   see correlation between every pair of columns ...
# 907   python - how to fillna by groupby outputs in p...
# 911   pipelining: chaining a pca and a logistic regr...
# 914   pandas.core.groupby.dataframegroupby.fillna — ...
# 915                 fillna with groupby pandas - -suche
# 917   pandas.dataframe.fillna — pandas 1.0.4 documen...
# 918                              fillna pandas - -suche
# 919   pandas.dataframe.groupby — pandas 1.0.4 docume...
# 920                            gropupby pandas - -suche
# 930   pandas.dataframe.fillna — pandas 1.0.4 documen...
# 932   python - using pandas crosstab with seaborn st...
# 933        pandas.crosstab — pandas 1.0.4 documentation
# 944   pandas - concat series onto dataframe with col...
# 946                              concat pandas - -suche
# 961                              fillna pandas - -suche
# 964   how to show all columns / rows of a pandas dat...
# 965   python - how do i expand the output display to...
# 970                 stratified sampling pandas - -suche
# 971   python - using pandas crosstab with seaborn st...
# 972                     plot a pandas crosstab - -suche
# 973        pandas.crosstab — pandas 1.0.4 documentation
# 974                            crosstab pandas - -suche
# 1000  python - change data type of columns in pandas...
# 1002  unicodedecodeerror when reading csv file in pa...
# 1003  unicodedecodeerror when reading csv file in pa...
# 1018             pandas dataframe: dtypes() function -
# 1019                              dtype pandas - -suche
# 1022  python - change data type of columns in pandas...
# 1023                       change dtype pandas - -suche
# 1025      treat decoding error pandas read.csv - -suche
# 1030       pandas.read_csv — pandas 1.0.4 documentation
# 1031                           pandas read.csv - -suche
# 1046  pandas.dataframe.idxmax — pandas 1.0.4 documen...
# 1047       pandas.read_csv — pandas 1.0.4 documentation
# 1053  pandas.dataframe.idxmax — pandas 1.0.4 documen...
# 1054                            .idxmax pandas - -suche
# 1120  pandas.dataframe.select_dtypes — pandas 1.0.4 ...
# 1127  indexing and selecting data — pandas 1.0.4 doc...
# 1130  python - how to drop rows of pandas dataframe ...
# 1131  python - how to drop rows of pandas dataframe ...
# 1132  drop records having na for certain columns pan...
# 1135  pandas.dataframe.drop — pandas 1.0.4 documenta...
# 1136                              .drop pandas - -suche
# 1137  python pandas : how to drop rows in dataframe ...
# 1138              drop row if condition pandas - -suche
# 1139  python - delete rows from a pandas dataframe b...
# 1143                            fill na pandas - -suche
# 1144      pandas.crosstab — pandas 0.23.4 documentation
# 1145  pandas.series.value_counts — pandas 1.0.4 docu...
# 1146  pandas.dataframe.iloc — pandas 1.0.4 documenta...
# 1151    pandas.series.mask — pandas 1.0.4 documentation
# 1154  overview of pandas data types - practical busi...
# 1155                         pandas data types - -suche
# 1177  pandas crosstab explained - practical business...
# 1180      pandas.crosstab — pandas 0.23.4 documentation
# 1181                  contingency table pandas - -suche
# 1182  pandas.series.value_counts — pandas 1.0.4 docu...
# 1184  python - how can i obtain the element-wise log...
# 1202         iterate over columns pandas - google-suche
# 1251               iterate over columns pandas - -suche
# 1261  python - how to iterate over columns of pandas...
# 1262  python - how to check if any value is nan in a...
# 1263  pandas.dataframe.apply — pandas 1.0.4 document...
# 1296         pandas.series — pandas 1.0.4 documentation
# 1315  good resource to learn fundamentals of pandas ...
# 1316  good resource to learn fundamentals of pandas ...
# 1317  python - get index of elements in pandas dataf...
# 1318  get index of elements that follow condition pa...
# 1319  pandas.index.get_loc — pandas 1.0.4 documentation
# 1320                        get indices pandas - -suche
# 1321  pandas.dataframe.index — pandas 1.0.4 document...
# 1322                              pandas foundations |
# 1323                      online pandas course - -suche
# 1324                     pandas series methods - -suche
# 1329                              apply pandas - -suche
# 1330                     apply in place pandas - -suche
# 1331     check if column has null value pandas - -suche
# 1333  sklearn.linear_model.logisticregression —  0.2...
# 1334               logistic regression sklearn - -suche
# 1376  python - plot correlation matrix using pandas ...
# 1380  how to create a correlation matrix using panda...
# 1384               logistic regression sklearn - -suche
# 1395                             .apply pandas - -suche
# 1396  can you use apply() in pandas to update in-pla...
# 1397                     apply in place pandas - -suche
# 1401  python - what are all the dtypes that pandas r...
# 1402                       dtype object pandas - -suche
# 1403      categorical data — pandas 1.0.4 documentation
# 1404   convert variables to categorical pandas - -suche
# 1406                               drop pandas - -suche
# 1407  python - selecting/excluding sets of columns i...
# 1408  python - delete column from pandas dataframe -...
# 1409             all columns except one pandas - -suche
# 1446          installation — pandas 1.0.4 documentation
# 1447          installation — pandas 1.0.4 documentation
# 1448                            install pandas - -suche
# 1520  [2003.09097] localized sketching for matrix mu...
# 1524  [2003.09097] localized sketching for matrix mu...
# 1669               linear regression in python - -suche
# 1670              pick specific rows in pandas - -suche
# 1671  python - how do i get the row count of a panda...
# 1672                               nrow pandas - -suche
# 1681  python - how do i create test and train sample...
# 1683   creating sample and test sets in pandas - -suche
# 1684  python - stratified sampling in pandas - stack...
# 1685                stratified sampling pandas - -suche
# 1690  logistic regression with a neural network mind...
# 1763  pandas.dataframe.groupby — pandas 1.0.4 docume...
# 1764  pandas.dataframe.join — pandas 1.0.4 documenta...
# 1765  pandas.dataframe.join — pandas 1.0.4 documenta...
# 1801                              .join pandas - -suche
# 1802                          learn pandas tutorials |
# 1804                            groupby pandas - -suche
# 1807                 get number of rows pandas - -suche
# 1809               groupby — pandas 1.0.4 documentation
# 1810                           group by pandas - -suche
# 1811  pandas.dataframe.sort_values — pandas 1.0.4 do...
# 1816                           group by pandas - -suche
# 1823                       value_counts pandas - -suche
# 1826  python - how to get the max/min value in panda...
# 1828           ignore nan in max python pandas - -suche
# 1840  how to export pandas dataframe to csv - toward...
# 1841             write dataframe to csv pandas - -suche
# 1844               create data frame in pandas - -suche
# 1846                stratified sampling pandas - -suche
# 1857                             logistic regression -
# 1858                             logistic regression -
# 1859                       logistic regression - -suche
# 1866  r - wald test in regression (ols and glms): t-...
# 1868  z statistic - wald test for logistic regressio...
# 1871  interpretation of r's output for binomial regr...
# 1872                 explanation of logistic regression
# 1897  r - wald test in regression (ols and glms): t-...
# 1903  z statistic - wald test for logistic regressio...
# 1905             z-values in logistic regression | .com
# 1906  regression - in a glm, is the log likelihood o...
# 1909  regression - generalized linear model and iden...
# 1915  [r] how to build a saturated model for logisti...
# 1916  deviance - logistic regression : how to obtain...
# 1917  timeline for answer to logistic regression : h...
# 1927                       logistic regression - -suche
# 1928  what is z value and pr(>|z|) in logistic regre...
# 1931  extract standard errors of coefficient linear ...
# 1933            standard error in r regression - -suche
# 1934      standard error in r regression - google-suche
# 1942                    logistic regression - wikipedia
# 1947  what is z value and pr(>|z|) in logistic regre...
# 1966  what is z value and pr(>|z|) in logistic regre...
# 1969  extract standard errors of coefficient linear ...
# 1974              firth logistic regression - wikipedia
# 2005  python - comparison of r, statmodels, sklearn ...
# 2006  different logistic regression results with r a...
# 2007  different logistic regression results with r a...
# 2008  different logistic regression results with r a...
# 2021                       logistic regression - -suche
# 2022  what is null and residual deviance in logistic...
# 2023  what is null and residual deviance in logistic...
# 2024           deviance in logistic regression - -suche
# 2042         deviance in logistic regression r - -suche
# 2046                    logistic regression - wikipedia
# 2047                       logistic regression - -suche
# 2048                 logistic regression - google-suche
# 2051  r calculate deviance residuals in a logistic r...
# 2054  r calculate deviance residuals in a logistic r...
# 2056  deviance residuals in logistic regression - cr...
# 2058  regression - deviance residuals - cross validated
# 2079  r calculate deviance residuals in a logistic r...
# 2080  how are deviance residuals calculated for logi...
# 2081  how are deviance residuals calculated for logi...
# 2105                       logistic regression - -suche
# 2106  pearson vs deviance residuals in logistic regr...
# 2108  what is y in deviance residuals for logistic r...
# 2111                             logistic regression -
# 2112             wikipedia logistic regression - -suche
# 2114           glm in r: logistic regression example -
# 2614  pandas dataframe: a lightweight intro - toward...
# 2655  pandas series: a lightweight intro - towards d...
# 2656                       pandas series - google-suche
# 2657  pandas.dataframe.apply — pandas 1.0.4 document...
# 2667  pandas series: a lightweight intro - towards d...
# 2693                             pandas series - -suche
# 2694                             pandas series - -suche
# 2696                              pandas.apply - -suche
# 2697                           group by pandas - -suche
# 2699                                         pandas.pdf
# 2702                           pandas read csv - -suche
# 2703                             pandas_cheat_sheet.pdf
# 2704                        pandas cheat sheet - -suche
# 2705                           pandas read csv - -suche
# 2815                                          pandas ·
# 2816                            install pandas - -suche
# 2817              pandas - python data analysis library
# 2872              pandas - python data analysis library
# 2873                            install pandas - -suche
# 2883                                    pandas - -suche
# 2978  r - exclude more than one columns when build l...
# 3130                     editing logistic regression –
# 3131                     editing logistic regression –
# 3141  explaining the output of logistic regression i...
# 3151  simply explained logistic regression with exam...
# 3275  explaining the output of logistic regression i...
# 3277  generalized linear models in r, part 2: unders...
# 3283  what is null and residual deviance in logistic...
# 3295  r - how to test for goodness of fit for a logi...
# 3300  checking goodness of fit for logistic regressi...
# 3301  checking goodness of fit for logistic regressi...
# 3307  r - how to test for goodness of fit for a logi...
# 3309  when do you need to standardize the variables ...
# 3312  regression - how exactly are standardized resi...
# 3322  4.2 logistic regression | interpretable machin...
# 3323  machine learning - why not approach classifica...
# 3324  pros and cons of logistic regression with bina...
# 3325           the logistic regression algorithm – .com
# 3326  advantages and disadvantages of logistic regre...
# 3346  residual values (residuals) in regression anal...
# 3351                             regression analysis -
# 3352                       logistic regression - -suche
# 3458  r - logistic regression model does not converg...
# 3540  statistics - logistic regression giving negati...
# 3541  statistics - logistic regression giving negati...
# 3542  linear regression predicting negative values |...
# 3543  predict outputs negative values for logit regr...
# 3544  predict outputs negative values for logit regr...
# 3545  glm in r logistic regression predicted probabi...
# 3546  glm in r logistic regression predicted probabi...
# 3547  how to predict using logistic regression in r ...
# 3548  how to predict using logistic regression in r ...
# 3587              titanic - logistic regression in r |
# 3588              titanic - logistic regression in r |
# 3591  titanic best linear regression accuracy r - -s...
# 3592   titanic best linear regression accuracy - -suche
# 3613  glm in r logistic regression predicted probabi...
# 3614  prediction using logistic regression in r - -s...
# 3615    linear regression predicting negative values |
# 3620  predicted probability using logistic regressio...
# 3621  how to predict using logistic regression in r ...
# 3626          logistic regression in r - stack overflow
# 3627            logistic regression in r stack - -suche
# 3628                  logistic regression in r - -suche
# 3668        logit regression | r data analysis examples
# 3670  coding systems for categorical variables in re...
# 3680                         logistic regression with r
# 3681                  logistic regression in r - -suche
# 3695        logit regression | r data analysis examples
# 3700  coding systems for categorical variables in re...
# 3701       regression on categorical variables - -suche
# 6534  university admission prediction using multiple...
# 6609            softmax regression - deeplearning.ai |
# 6622  hyperparameters tuning in practice: pandas vs....
# 6964  machine learning - linear regression with mult...
# 6967             linear regression with one variable |
# 6971  machine learning - linear regression with one ...
# 7214  logistic regression cost function - deeplearni...
# 7215  clarification about upcoming logistic regressi...
# 7216           logistic regression - deeplearning.ai |
# 7227  logistic regression with a neural network mind...
# 7228  logistic regression with a neural network mind...
# 7229  logistic_regression_with_a_neural_network_mind...
# 7272  vectorizing logistic regression's gradient out...
# 7273  vectorizing logistic regression - deeplearning...
# 7279  logistic regression gradient descent - deeplea...
# 9633          machine learning - logistic regression |
#
#                                                     url  \
# 137               https://www.kaggle.com/learn/overview
# 509   https://pandas.pydata.org/pandas-docs/stable/r...
# 510   https://www.google.com/search?q=.random+pandas...
# 629   chrome-extension://klbibkeccnjlkjkiokjodocebaj...
# 635   chrome-extension://klbibkeccnjlkjkiokjodocebaj...
# 651   https://pandas.pydata.org/pandas-docs/stable/r...
# 652   https://pandas.pydata.org/pandas-docs/stable/r...
# 653   https://www.google.com/search?q=aggregate+pand...
# 654   https://www.google.com/search?q=.mode+pandas&o...
# 655   https://pandas.pydata.org/pandas-docs/stable/r...
# 656   https://www.google.com/search?q=pandas+concat&...
# 657   https://pandas.pydata.org/pandas-docs/stable/r...
# 658   https://pandas.pydata.org/pandas-docs/stable/u...
# 659   https://www.google.com/search?q=concatenate+on...
# 660   https://www.google.com/search?q=concat+pandas&...
# 661   https://pandas.pydata.org/pandas-docs/stable/r...
# 691   https://stackoverflow.com/questions/38088652/p...
# 692   https://www.google.com/search?q=convert+string...
# 768   https://stackoverflow.com/questions/36398417/p...
# 769   chrome-extension://klbibkeccnjlkjkiokjodocebaj...
# 770   https://stackoverflow.com/questions/37239627/c...
# 771   chrome-extension://klbibkeccnjlkjkiokjodocebaj...
# 779   https://www.google.com/search?q=concat+pandas&...
# 780   https://www.google.com/search?q=replace+value+...
# 787   https://pandas.pydata.org/pandas-docs/stable/u...
# 824   https://stackoverflow.com/questions/46759141/c...
# 843   chrome-extension://klbibkeccnjlkjkiokjodocebaj...
# 845   chrome-extension://klbibkeccnjlkjkiokjodocebaj...
# 851         https://www.youtube.com/watch?v=BFaadIqWlAg
# 881   https://www.google.com/search?q=chi+square+tes...
# 883   https://stackoverflow.com/questions/48035381/c...
# 884   https://www.google.com/search?biw=1440&bih=821...
# 889   https://kite.com/python/answers/how-to-find-th...
# 890   https://www.google.com/search?q=see+correlatio...
# 907   https://stackoverflow.com/questions/41680089/h...
# 911   https://scikit-learn.org/stable/auto_examples/...
# 914   https://pandas.pydata.org/pandas-docs/stable/r...
# 915   https://www.google.com/search?q=fillna+with+gr...
# 917   https://pandas.pydata.org/pandas-docs/stable/r...
# 918   https://www.google.com/search?q=fillna+pandas&...
# 919   https://pandas.pydata.org/pandas-docs/stable/r...
# 920   https://www.google.com/search?q=gropupby+panda...
# 930   chrome-extension://klbibkeccnjlkjkiokjodocebaj...
# 932   chrome-extension://klbibkeccnjlkjkiokjodocebaj...
# 933   chrome-extension://klbibkeccnjlkjkiokjodocebaj...
# 944   https://stackoverflow.com/questions/39047915/c...
# 946   https://www.google.com/search?q=concat+pandas&...
# 961   https://www.google.com/search?q=fillna+pandas&...
# 964   https://towardsdatascience.com/how-to-show-all...
# 965   https://stackoverflow.com/questions/11707586/h...
# 970   https://www.google.com/search?q=stratified+sam...
# 971   https://stackoverflow.com/questions/43544694/u...
# 972   https://www.google.com/search?q=plot+a+pandas+...
# 973   https://pandas.pydata.org/pandas-docs/stable/r...
# 974   https://www.google.com/search?q=crosstab+panda...
# 1000  chrome-extension://klbibkeccnjlkjkiokjodocebaj...
# 1002  https://stackoverflow.com/questions/18171739/u...
# 1003  chrome-extension://klbibkeccnjlkjkiokjodocebaj...
# 
chrome-extension://klbibkeccnjlkjkiokjodocebaj...
# 3587  https://www.kaggle.com/jeremyd/titanic-logisti...
# 3588  https://www.kaggle.com/jeremyd/titanic-logisti...
# 3591  https://www.google.com/search?sxsrf=ALeKk02x65...
# 3592  https://www.google.com/search?q=titanic+best+l...
# 3613  https://www.theanalysisfactor.com/r-tutorial-g...
# 3614  https://www.google.com/search?q=prediction+usi...
# 3615  https://www.kaggle.com/c/bike-sharing-demand/d...
# 3620  https://stackoverflow.com/questions/38055848/p...
# 3621  https://www.google.com/search?q=how+to+predict...
# 3626  https://stackoverflow.com/questions/11587270/l...
# 3627  https://www.google.com/search?sxsrf=ALeKk01icj...
# 3628  https://www.google.com/search?q=logistic+regre...
# 3668  chrome-extension://klbibkeccnjlkjkiokjodocebaj...
# 3670  chrome-extension://klbibkeccnjlkjkiokjodocebaj...
# 3680  http://r-statistics.co/Logistic-Regression-Wit...
# 3681  https://www.google.com/search?q=logistic+regre...
# 3695  https://stats.idre.ucla.edu/r/dae/logit-regres...
# 3700  https://stats.idre.ucla.edu/spss/faq/coding-sy...
# 3701  https://www.google.com/search?q=regression+on+...
# 6534  https://www.coursera.org/projects/machine-lear...
# 6609  https://www.coursera.org/learn/deep-neural-net...
# 6622  https://www.coursera.org/learn/deep-neural-net...
# 6964  https://www.coursera.org/learn/machine-learnin...
# 6967  https://www.coursera.org/learn/machine-learnin...
# 6971  https://www.coursera.org/learn/machine-learnin...
# 7214  https://www.coursera.org/learn/neural-networks...
# 7215  https://www.coursera.org/learn/neural-networks...
# 7216  https://www.coursera.org/learn/neural-networks...
# 7227  https://www.coursera.org/learn/neural-networks...
# 7228  https://www.coursera.org/learn/neural-networks...
# 7229  https://msrpqnwuuolskieuvlnkrb.coursera-apps.o...
# 7272  https://www.coursera.org/learn/neural-networks...
# 7273  https://www.coursera.org/learn/neural-networks...
# 7279  https://www.coursera.org/learn/neural-networks...
# 9633  https://www.coursera.org/learn/machine-learnin...
#
#                                domains
# 137                             kaggle
# 509                             pydata
# 510                             google
# 629   klbibkeccnjlkjkiokjodocebajanakg
# 635   klbibkeccnjlkjkiokjodocebajanakg
# 651                             pydata
# 652                             pydata
# 653                             google
# 654                             google
# 655                             pydata
# 656                             google
# 657                             pydata
# 658                             pydata
# 659                             google
# 660                             google
# 661                             pydata
# 691                      stackoverflow
# 692                             google
# 768                      stackoverflow
# 769   klbibkeccnjlkjkiokjodocebajanakg
# 770                      stackoverflow
# 771   klbibkeccnjlkjkiokjodocebajanakg
# 779                             google
# 780                             google
# 787                             pydata
# 824                      stackoverflow
# 843   klbibkeccnjlkjkiokjodocebajanakg
# 845   klbibkeccnjlkjkiokjodocebajanakg
# 851                            youtube
# 881                             google
# 883                      stackoverflow
# 884                             google
# 889                               kite
# 890                             google
# 907                      stackoverflow
# 911                       scikit-learn
# 914                             pydata
# 915                             google
# 917                             pydata
# 918                             google
# 919                             pydata
# 920                             google
# 930   klbibkeccnjlkjkiokjodocebajanakg
# 932   klbibkeccnjlkjkiokjodocebajanakg
# 933   klbibkeccnjlkjkiokjodocebajanakg
# 944                      stackoverflow
# 946                             google
# 961                             google
# 964                 towardsdatascience
# 965                      stackoverflow
# 970                             google
# 971                      stackoverflow
# 972                             google
# 973                             pydata
# 974                             google
# 1000  klbibkeccnjlkjkiokjodocebajanakg
# 1002                     stackoverflow
# 1003  klbibkeccnjlkjkiokjodocebajanakg
# 1018                        w3resource
# 1019                            google
# 1022                     stackoverflow
# 1023                            google
# 1025                            google
# 1030                            pydata
# 1031                            google
# 1046  klbibkeccnjlkjkiokjodocebajanakg
# 1047  klbibkeccnjlkjkiokjodocebajanakg
# 1053                            pydata
# 1054                            google
# 1120                            pydata
# 1127                            pydata
# 1130  klbibkeccnjlkjkiokjodocebajanakg
# 1131                     stackoverflow
# 1132                            google
# 1135                            pydata
# 1136                            google
# 1137                       thispointer
# 1138                            google
# 1139                     stackoverflow
# 1143                            google
# 1144  klbibkeccnjlkjkiokjodocebajanakg
# 1145  klbibkeccnjlkjkiokjodocebajanakg
# 1146                            pydata
# 1151                            pydata
# 1154                          pbpython
# 1155                            google
# 1177                          pbpython
# 1180                            pydata
# 1181                            google
# 1182                            pydata
# 1184                     stackoverflow
# 1202  klbibkeccnjlkjkiokjodocebajanakg
# 1251                            google
# 1261                     stackoverflow
# 1262                     stackoverflow
# 1263                            pydata
# 1296                            pydata
# 1315                            google
# 1316                            google
# 1317                     stackoverflow
# 1318                            google
# 1319                            pydata
# 1320                            google
# 1321                            pydata
# 1322                          datacamp
# 1323                            google
# 1324                            google
# 1329                            google
# 1330                            google
# 1331                            google
# 1333                      scikit-learn
# 1334                            google
# 1376                     stackoverflow
# 1380                        datatofish
# 1384                            google
# 1395                            google
# 1396                        codecademy
# 1397                            google
# 1401                     stackoverflow
# 1402                            google
# 1403                            pydata
# 1404                            google
# 1406                            google
# 1407                     stackoverflow
# 1408                     stackoverflow
# 1409                            google
# 1446  klbibkeccnjlkjkiokjodocebajanakg
# 1447                            pydata
# 1448                            google
# 1520  klbibkeccnjlkjkiokjodocebajanakg
# 1524                             arxiv
# 1669                            google
# 1670                            google
# 1671                     stackoverflow
# 1672                            google
# 1681                     stackoverflow
# 1683                            google
# 1684                     stackoverflow
# 1685                            google
# 1690                          coursera
# 1763  klbibkeccnjlkjkiokjodocebajanakg
# 1764                            pydata
# 1765  klbibkeccnjlkjkiokjodocebajanakg
# 1801                            google
# 1802                            kaggle
# 1804                            google
# 1807                            google
# 1809                            pydata
# 1810                            google
# 1811                            pydata
# 1816                            google
# 1823                            google
# 1826                     stackoverflow
# 1828                            google
# 1840                towardsdatascience
# 1841                            google
# 1844                            google
# 1846                            google
# 1857                         wikipedia
# 1858                         wikipedia
# 1859                            google
# 1866  klbibkeccnjlkjkiokjodocebajanakg
# 1868  klbibkeccnjlkjkiokjodocebajanakg
# 1871                     stackexchange
# 1872               informationbuilders
# 1897                     stackexchange
# 1903                     stackexchange
# 1905        logisticregressionanalysis
# 1906                     stackexchange
# 1909                     stackexchange
# 1915                              ethz
# 1916                     stackexchange
# 1917                     stackexchange
# 1927                            google
# 1928  klbibkeccnjlkjkiokjodocebajanakg
# 1931  klbibkeccnjlkjkiokjodocebajanakg
# 1933                            google
# 1934  klbibkeccnjlkjkiokjodocebajanakg
# 1942  klbibkeccnjlkjkiokjodocebajanakg
# 1947                   analyticsvidhya
# 1966                   analyticsvidhya
# 1969                     stackexchange
# 1974  klbibkeccnjlkjkiokjodocebajanakg
# 2005                     stackoverflow
# 2006                     stackoverflow
# 2007                     stackoverflow
# 2008                     stackoverflow
# 2021                            google
# 2022                   analyticsvidhya
# 2023                   analyticsvidhya
# 2024                            google
# 2042                            google
# 2046  klbibkeccnjlkjkiokjodocebajanakg
# 2047                            google
# 2048  klbibkeccnjlkjkiokjodocebajanakg
# 2051                     stackexchange
# 2054                     stackexchange
# 2056                     stackexchange
# 2058                     stackexchange
# 2079  klbibkeccnjlkjkiokjodocebajanakg
# 2080                            google
# 2081  klbibkeccnjlkjkiokjodocebajanakg
# 2105                            google
# 2106                     stackexchange
# 2108                            google
# 2111                         wikipedia
# 2112                            google
# 2114                           youtube
# 2614                towardsdatascience
# 2655  klbibkeccnjlkjkiokjodocebajanakg
# 2656  klbibkeccnjlkjkiokjodocebajanakg
# 2657  klbibkeccnjlkjkiokjodocebajanakg
# 2667                towardsdatascience
# 2693                            google
# 2694                            google
# 2696                            google
# 2697                            google
# 2699
# 2702                            google
# 2703                            pydata
# 2704                            google
# 2705                            google
# 2815                              pypi
# 2816                            google
# 2817                            pydata
# 2872                            pydata
# 2873                            google
# 2883                            google
# 2978                     stackoverflow
# 3130                            medium
# 3131                            medium
# 3141                            google
# 3151                towardsdatascience
# 3275                            google
# 3277                 theanalysisfactor
# 3283                   analyticsvidhya
# 3295  klbibkeccnjlkjkiokjodocebajanakg
# 3300                            google
# 3301  klbibkeccnjlkjkiokjodocebajanakg
# 3307                     stackexchange
# 3309                   statisticsbyjim
# 3312                     stackexchange
# 3322                            github
# 3323                     stackexchange
# 3324                     stackexchange
# 3325              machinelearning-blog
# 3326                            google
# 3346                   statisticshowto
# 3351                         wikipedia
# 3352                            google
# 3458                     stackexchange
# 3540                     stackexchange
# 3541  klbibkeccnjlkjkiokjodocebajanakg
# 3542  klbibkeccnjlkjkiokjodocebajanakg
# 3543                            google
# 3544  klbibkeccnjlkjkiokjodocebajanakg
# 3545  klbibkeccnjlkjkiokjodocebajanakg
# 3546  klbibkeccnjlkjkiokjodocebajanakg
# 3547                            google
# 3548  klbibkeccnjlkjkiokjodocebajanakg
# 3587                            kaggle
# 3588                            kaggle
# 3591                            google
# 3592                            google
# 3613                 theanalysisfactor
# 3614                            google
# 3615                            kaggle
# 3620                     stackoverflow
# 3621                            google
# 3626                     stackoverflow
# 3627                            google
# 3628                            google
# 3668  klbibkeccnjlkjkiokjodocebajanakg
# 3670  klbibkeccnjlkjkiokjodocebajanakg
# 3680                      r-statistics
# 3681                            google
# 3695                              ucla
# 3700                              ucla
# 3701                            google
# 6534                          coursera
# 6609                          coursera
# 6622                          coursera
# 6964                          coursera
# 6967                          coursera
# 6971                          coursera
# 7214                          coursera
# 7215                          coursera
# 7216                          coursera
# 7227                          coursera
# 7228                          coursera
# 7229                     coursera-apps
# 7272                          coursera
# 7273                          coursera
# 7279                          coursera
# 9633                          coursera
