# %%
import pandas as pd
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
import tldextract
import scipy.sparse
from sklearn.feature_extraction import text
from sklearn import metrics
from sklearn.metrics import pairwise_distances

# %%
pd.set_option('display.max_rows', None)
df = pd.read_csv('history.csv', parse_dates = True)

# %%
# Extract domains from URL
domains = df.url.apply(lambda x: tldextract.extract(x).domain)
df = pd.concat([df, domains.rename('domains')], axis = 1)

def f(x):
    t = str(x.title).lower().strip()
    if t != x.domains:
        x.title = t.replace(x.domains, "")
    if x.title == 'nan':
        x.title = x.domains
    return x

df = df.apply(f, axis = 1)

# %%
# Model Feature Selection
numeric_cols = []
useful_cols = numeric_cols
categorical_cols = []
categorical_cols_int = [x+"_int" for x in categorical_cols]
useful_cols.extend(categorical_cols_int)

# %%
# Encode categorical cols as numeric
for c in categorical_cols:
    new = pd.Series((pd.factorize(df[c])[0]+1))
    df = pd.concat([df, new.rename(c+"_int")], axis = 1)

# %%
# useful_cols.extend(list(title_df.columns))

# %%
def cluster_df(df_param, iteration, n_clusters):        
    # Preprocessing
    local_df = df_param.copy()
    
    my_stop_words = text.ENGLISH_STOP_WORDS.union(["suche", "search"])
    vectorizer = TfidfVectorizer(stop_words=my_stop_words, max_features = 100)
    
    X = vectorizer.fit_transform(local_df.title[~pd.isnull(local_df.title)])


    km = KMeans(n_clusters=n_clusters, init='k-means++', max_iter=300, n_init=10)
    km.fit(X)
    
    pred_y = pd.Series(km.predict(X))
    pred_y.index = local_df.index

    local_df = pd.concat([local_df, pred_y.rename('Cluster'+str(iteration))], axis = 1)
    
    print("Top terms per cluster:")
    order_centroids = km.cluster_centers_.argsort()[:, ::-1]
    terms = vectorizer.get_feature_names()
    for i in range(n_clusters):
        print("Cluster %d:" % i, end=' | ')
        print("Cluster size = ",local_df['Cluster'+str(iteration)].value_counts()[i], end=' | ')
        for ind in order_centroids[i, :10]:
            print(' %s' % terms[ind], end=' | ')
        print()
    labels = km.labels_
    print('Silhouette Coefficient = ', metrics.silhouette_score(X, labels, metric='euclidean'))
    
    return local_df

# %%
def evaluate(local_df, n_clusters = 5, iteration = 0, max_iteration = 10):
    max_cluster_size = local_df.shape[0]
    df_rev = local_df
    while max_cluster_size > df.shape[0]*0.1 and iteration < max_iteration:
        if 'Cluster'+str(iteration-1) in list(df_rev.columns.values):
            df_rev = cluster_df(df_rev[df_rev['Cluster'+str(iteration-1)] == df_rev['Cluster'+str(iteration-1)].value_counts().idxmax()], iteration, n_clusters)

        else:
            df_rev = cluster_df(df_rev, iteration, n_clusters)
        max_cluster_size = df_rev['Cluster'+str(iteration)].value_counts().max()
        iteration = iteration+1

# %%
evaluate(df, 10)
# Out:
# Top terms per cluster:
# Cluster 0: | Cluster size =  458 |  overflow |  stack |  python |  list |  pandas |  string |  data |  using |  algorithm |  learn |
# Cluster 1: | Cluster size =  8449 |  online |  india |  stories |  courses |  chrome |  mathematics |  pandas |  web |  algorithms |  com |
# Cluster 2: | Cluster size =  160 |  paths |  shortest |  discussions |  structures |  graph |  data |  home |  stanford |  university |  course |
# Cluster 3: | Cluster size =  593 |  netflix |  best |  learning |  lamma |  graph |  edu |  episode |  exchange |  explore |  fateh |
# Cluster 4: | Cluster size =  330 |  python |  string |  list |  time |  best |  set |  pandas |  using |  learn |  neural |
# Cluster 5: | Cluster size =  324 |  maps |  com |  world |  linear |  video |  using |  documentation |  edu |  episode |  exchange |
# Cluster 6: | Cluster size =  386 |  learning |  machine |  titanic |  deep |  jobs |  mathematics |  neural |  home |  data |  opencourseware |
# Cluster 7: | Cluster size =  269 |  university |  stanford |  algorithm |  maps |  analysis |  problem |  ashoka |  programming |  2020 |  india |
# Cluster 8: | Cluster size =  131 |  jaipur |  maps |  home |  india |  university |  graph |  edu |  episode |  exchange |  explore |
# Cluster 9: | Cluster size =  240 |  neural |  networks |  convolutional |  deep |  discussions |  home |  learning |  course |  algorithms |  deeplearning |
# Cluster 10: | Cluster size =  202 |  ai |  deeplearning |  deep |  neural |  learning |  test |  networks |  regression |  logistic |  data |
# Cluster 11: | Cluster size =  274 |  island |  lamma |  maps |  world |  graph |  edu |  episode |  exchange |  explore |  fateh |
# Cluster 12: | Cluster size =  105 |  test |  cross |  stack |  overflow |  regression |  logistic |  data |  pandas |  documentation |  mathematics |
# Cluster 13: | Cluster size =  185 |  gmail |  com |  kshitijkapoor08 |  2020 |  new |  kshitij |  kapoor |  mail |  ashoka |  pdf |
# Cluster 14: | Cluster size =  216 |  algs |  stanford |  beaunus |  master |  txt |  test |  home |  using |  algorithms |  episode |
# Cluster 15: | Cluster size =  215 |  season |  premium |  episode |  watch |  disney |  sunny |  philadelphia |  10 |  free |  documentation |
# Cluster 16: | Cluster size =  221 |  data |  science |  python |  analysis |  pandas |  learning |  discussions |  machine |  home |  structures |
# Cluster 17: | Cluster size =  148 |  programming |  algorithms |  discussions |  python |  home |  computer |  data |  10 |  learning |  world |
# Cluster 18: | Cluster size =  153 |  documentation |  learn |  data |  pandas |  10 |  python |  algorithm |  using |  cross |  logistic |
# Cluster 19: | Cluster size =  113 |  google |  chrome |  new |  regression |  stack |  using |  logistic |  pandas |  data |  exchange |
# Silhouette Coefficient =  0.49116495399548427
# Top terms per cluster:
# Cluster 0: | Cluster size =  6279 |  news |  german |  best |  corona |  linkedin |  sign |  regression |  2020 |  world |  ayaz |
# Cluster 1: | Cluster size =  114 |  videos |  photos |  youtube |  ashoka |  video |  india |  course |  kapoor |  kshitij |  stack |
# Cluster 2: | Cluster size =  62 |  drive |  10 |  new |  photos |  problem |  kshitij |  home |  fateh |  free |  german |
# Cluster 3: | Cluster size =  140 |  stories |  german |  com |  web |  youtube |  index |  explore |  fateh |  free |  germany |
# Cluster 4: | Cluster size =  164 |  india |  best |  science |  computer |  free |  information |  coronavirus |  news |  jobs |  help |
# Cluster 5: | Cluster size =  106 |  pandas |  series |  learn |  index |  join |  stack |  youtube |  help |  explore |  fateh |
# Cluster 6: | Cluster size =  194 |  chrome |  store |  web |  new |  youtube |  latex |  math |  best |  home |  linear |
# Cluster 7: | Cluster size =  109 |  ashoka |  kapoor |  kshitij |  mail |  university |  alumni |  edu |  new |  help |  19 |
# Cluster 8: | Cluster size =  101 |  com |  plain |  free |  kapoor |  kshitij |  jobs |  watch |  home |  online |  coronavirus |
# Cluster 9: | Cluster size =  208 |  mathematics |  exchange |  stack |  opencourseware |  algebra |  linear |  matrices |  analysis |  probability |  latex |
# Cluster 10: | Cluster size =  122 |  courses |  tum |  theory |  math |  computer |  science |  analysis |  algebra |  free |  course |
# Cluster 11: | Cluster size =  122 |  khan |  ali |  fateh |  nusrat |  ustad |  official |  hd |  video |  live |  best |
# Cluster 12: | Cluster size =  80 |  home |  notebook |  news |  coronavirus |  india |  jobs |  com |  web |  10 |  vfs |
# Cluster 13: | Cluster size =  210 |  online |  free |  courses |  latex |  join |  münchen |  watch |  course |  tv |  german |
# Cluster 14: | Cluster size =  63 |  pdf |  2020 |  10 |  time |  19 |  theory |  pandas |  math |  edu |  new |
# Cluster 15: | Cluster size =  92 |  problem |  set |  time |  design |  10 |  2020 |  analysis |  algebra |  linear |  algorithms |
# Cluster 16: | Cluster size =  64 |  algorithms |  design |  analysis |  course |  pdf |  science |  computer |  live |  opencourseware |  theory |
# Cluster 17: | Cluster size =  59 |  conquer |  divide |  randomized |  searching |  sorting |  algorithms |  home |  course |  online |  kapoor |
# Cluster 18: | Cluster size =  90 |  explore |  youtube |  india |  fateh |  free |  german |  germany |  hd |  help |  hindi |
# Cluster 19: | Cluster size =  70 |  submission |  time |  best |  youtube |  explore |  fateh |  free |  german |  germany |  hd |
# Silhouette Coefficient =  0.5169567833516784
# Top terms per cluster:
# Cluster 0: | Cluster size =  44 |  wikipedia |  personal |  titanic |  information |  matrix |  theorem |  variables |  deviance |  logistic |  news |
# Cluster 1: | Cluster size =  5352 |  news |  world |  2020 |  titanic |  coronavirus |  best |  audiobooks |  live |  library |  ayaz |
# Cluster 2: | Cluster size =  48 |  youtube |  german |  rogan |  joe |  help |  new |  hindi |  english |  meaning |  computer |
# Cluster 3: | Cluster size =  46 |  time |  tv |  series |  comedy |  hindi |  validated |  code |  cross |  does |  plain |
# Cluster 4: | Cluster size =  41 |  tattoo |  tightrope |  guy |  youtube |  download |  exercise |  farid |  female |  final |  free |
# Cluster 5: | Cluster size =  81 |  regression |  logistic |  validated |  cross |  linear |  deviance |  model |  analysis |  variables |  glm |
# Cluster 6: | Cluster size =  51 |  video |  ard |  mediathek |  series |  does |  matrix |  math |  best |  help |  computer |
# Cluster 7: | Cluster size =  53 |  sign |  youtube |  help |  exercise |  farid |  female |  final |  free |  german |  germany |
# Cluster 8: | Cluster size =  46 |  scratch |  hindi |  download |  learn |  kaggle |  glm |  exercise |  farid |  kapoor |  female |
# Cluster 9: | Cluster size =  34 |  kaitlin |  olson |  youtube |  help |  exercise |  farid |  female |  final |  free |  german |
# Cluster 10: | Cluster size =  47 |  kapoor |  kshitij |  linkedin |  help |  exercise |  farid |  female |  final |  free |  german |
# Cluster 11: | Cluster size =  43 |  mac |  download |  index |  free |  check |  latex |  vs |  10 |  computer |  best |
# Cluster 12: | Cluster size =  54 |  linkedin |  help |  youtube |  hindi |  exercise |  farid |  female |  final |  free |  german |
# Cluster 13: | Cluster size =  55 |  theory |  big |  probability |  week |  learn |  index |  series |  new |  news |  information |
# Cluster 14: | Cluster size =  29 |  final |  19 |  exercise |  index |  farid |  female |  free |  german |  germany |  glm |
# Cluster 15: | Cluster size =  27 |  introduction |  exercise |  probability |  new |  kaggle |  hindi |  scratch |  theory |  germany |  english |
# Cluster 16: | Cluster size =  33 |  female |  comedians |  comedy |  best |  youtube |  hindi |  final |  free |  german |  germany |
# Cluster 17: | Cluster size =  64 |  computer |  science |  information |  2020 |  probability |  analysis |  institute |  learn |  check |  germany |
# Cluster 18: | Cluster size =  62 |  corona |  counter |  tv |  coronavirus |  19 |  news |  2020 |  youtube |  help |  final |
# Cluster 19: | Cluster size =  69 |  german |  learn |  best |  comedy |  tv |  germany |  series |  english |  new |  math |
# Silhouette Coefficient =  0.5480710743861592
# Top terms per cluster:
# Cluster 0: | Cluster size =  4607 |  news |  coronavirus |  math |  linear |  index |  mediathek |  new |  vfs |  institute |  learn |
# Cluster 1: | Cluster size =  36 |  help |  germany |  new |  covid |  19 |  study |  personal |  10 |  hindi |  farid |
# Cluster 2: | Cluster size =  41 |  live |  tv |  covid |  19 |  news |  coronavirus |  english |  hindi |  deutsch |  ard |
# Cluster 3: | Cluster size =  46 |  best |  free |  personal |  cross |  school |  learn |  2020 |  10 |  math |  coronavirus |
# Cluster 4: | Cluster size =  35 |  library |  world |  categorical |  learn |  germany |  english |  exercise |  experience |  fareed |  farid |
# Cluster 5: | Cluster size =  42 |  jupyter |  notebook |  opening |  personal |  linear |  für |  download |  english |  exercise |  experience |
# Cluster 6: | Cluster size =  44 |  titanic |  kaggle |  model |  english |  hindi |  games |  download |  exercise |  experience |  fareed |
# Cluster 7: | Cluster size =  51 |  audiobooks |  hindi |  meaning |  series |  germany |  english |  exercise |  experience |  fareed |  farid |
# Cluster 8: | Cluster size =  61 |  ayaz |  abu |  muhammad |  fareed |  farid |  na |  ki |  studio |  best |  2020 |
# Cluster 9: | Cluster size =  49 |  2020 |  germany |  mit |  download |  hindi |  mediathek |  algebra |  vs |  tiddlywiki |  linear |
# Cluster 10: | Cluster size =  64 |  world |  map |  news |  10 |  free |  coronavirus |  louis |  vs |  plain |  kaggle |
# Cluster 11: | Cluster size =  33 |  joe |  rogan |  experience |  world |  games |  download |  english |  exercise |  fareed |  farid |
# Cluster 12: | Cluster size =  25 |  list |  check |  vfs |  vs |  2020 |  young |  english |  exercise |  experience |  fareed |
# Cluster 13: | Cluster size =  40 |  nusrat |  young |  games |  download |  english |  exercise |  experience |  fareed |  farid |  free |
# Cluster 14: | Cluster size =  32 |  exercise |  kaggle |  categorical |  model |  random |  cross |  variables |  für |  english |  experience |
# Cluster 15: | Cluster size =  32 |  theorem |  analysis |  algebra |  series |  linear |  young |  games |  english |  exercise |  experience |
# Cluster 16: | Cluster size =  30 |  plain |  persepective |  notes |  die |  does |  download |  english |  exercise |  experience |  fareed |
# Cluster 17: | Cluster size =  28 |  code |  vs |  kaggle |  notes |  studio |  tiddlywiki |  best |  personal |  notebook |  linear |
# Cluster 18: | Cluster size =  31 |  adele |  young |  glm |  english |  exercise |  experience |  fareed |  farid |  free |  function |
# Cluster 19: | Cluster size =  25 |  settings |  account |  young |  games |  download |  english |  exercise |  experience |  fareed |  farid |
# Silhouette Coefficient =  0.5806371333325414
# Top terms per cluster:
# Cluster 0: | Cluster size =  28 |  meaning |  english |  math |  na |  algorithm |  word |  die |  distribution |  docs |  does |
# Cluster 1: | Cluster size =  4042 |  coronavirus |  index |  vfs |  algebra |  linear |  gupta |  function |  random |  using |  translate |
# Cluster 2: | Cluster size =  27 |  learn |  kaggle |  analysis |  word |  functions |  die |  distribution |  docs |  does |  download |
# Cluster 3: | Cluster size =  50 |  institute |  information |  indian |  personal |  vs |  study |  model |  overview |  coronavirus |  19 |
# Cluster 4: | Cluster size =  57 |  news |  overview |  germany |  covid |  analysis |  coronavirus |  19 |  indian |  study |  global |
# Cluster 5: | Cluster size =  27 |  latex |  math |  free |  cross |  tiddlywiki |  word |  function |  die |  distribution |  docs |
# Cluster 6: | Cluster size =  28 |  math |  germany |  functions |  algorithm |  vs |  free |  die |  distribution |  docs |  does |
# Cluster 7: | Cluster size =  27 |  matrix |  analysis |  correlation |  numpy |  vs |  linear |  software |  using |  factor |  english |
# Cluster 8: | Cluster size =  22 |  string |  studio |  categorical |  variables |  deviance |  die |  distribution |  docs |  does |  download |
# Cluster 9: | Cluster size =  23 |  does |  na |  kaggle |  coronavirus |  word |  series |  categorical |  variables |  random |  global |
# Cluster 10: | Cluster size =  26 |  10 |  games |  free |  indian |  jobs |  personal |  study |  germany |  factor |  deviance |
# Cluster 11: | Cluster size =  34 |  tv |  series |  study |  coronavirus |  10 |  free |  deviance |  die |  distribution |  docs |
# Cluster 12: | Cluster size =  21 |  audible |  book |  using |  für |  die |  distribution |  docs |  does |  download |  english |
# Cluster 13: | Cluster size =  19 |  module |  word |  microsoft |  function |  die |  distribution |  docs |  does |  download |  english |
# Cluster 14: | Cluster size =  38 |  cross |  validated |  model |  glm |  linear |  deviance |  factor |  random |  distribution |  correlation |
# Cluster 15: | Cluster size =  38 |  mediathek |  ard |  der |  mit |  die |  für |  english |  2019 |  gupta |  free |
# Cluster 16: | Cluster size =  29 |  new |  factor |  notes |  sklearn |  2019 |  tv |  personal |  download |  kaggle |  vfs |
# Cluster 17: | Cluster size =  23 |  account |  developer |  download |  news |  word |  function |  die |  distribution |  docs |  does |
# Cluster 18: | Cluster size =  20 |  distribution |  plot |  check |  word |  deutscher |  deviance |  die |  docs |  does |  download |
# Cluster 19: | Cluster size =  28 |  tiddlywiki |  plancker |  personal |  linear |  using |  vs |  new |  index |  factor |  distribution |
# Silhouette Coefficient =  0.599305791686629
# Top terms per cluster:
# Cluster 0: | Cluster size =  3615 |  studio |  column |  docs |  jobs |  für |  microsoft |  functions |  free |  models |  download |
# Cluster 1: | Cluster size =  29 |  numpy |  v1 |  manual |  random |  overview |  functions |  die |  direct |  disney |  docs |
# Cluster 2: | Cluster size =  21 |  germany |  coronavirus |  check |  vfs |  scholarship |  study |  vs |  covid |  global |  19 |
# Cluster 3: | Cluster size =  21 |  louis |  ck |  index |  louie |  games |  direct |  disney |  docs |  download |  english |
# Cluster 4: | Cluster size =  19 |  translate |  word |  games |  die |  direct |  disney |  docs |  download |  english |  free |
# Cluster 5: | Cluster size =  17 |  kaggle |  categorical |  germany |  direct |  disney |  docs |  download |  english |  free |  function |
# Cluster 6: | Cluster size =  32 |  algebra |  linear |  mit |  english |  für |  germany |  direct |  disney |  docs |  download |
# Cluster 7: | Cluster size =  19 |  gupta |  software |  word |  für |  die |  direct |  disney |  docs |  download |  english |
# Cluster 8: | Cluster size =  19 |  lstm |  jazz |  improvisation |  für |  die |  direct |  disney |  docs |  download |  english |
# Cluster 9: | Cluster size =  15 |  direct |  word |  games |  die |  disney |  docs |  download |  english |  free |  function |
# Cluster 10: | Cluster size =  14 |  day |  function |  word |  games |  direct |  disney |  docs |  download |  english |  free |
# Cluster 11: | Cluster size =  29 |  coronavirus |  week |  covid |  19 |  2019 |  global |  things |  free |  algebra |  germany |
# Cluster 12: | Cluster size =  39 |  vfs |  book |  global |  germany |  covid |  für |  direct |  disney |  docs |  download |
# Cluster 13: | Cluster size =  18 |  deutsch |  die |  für |  games |  direct |  disney |  docs |  download |  english |  free |
# Cluster 14: | Cluster size =  21 |  using |  categorical |  random |  movie |  log |  check |  decision |  san |  gta |  tree |
# Cluster 15: | Cluster size =  35 |  index |  gta |  san |  games |  movie |  software |  2019 |  ki |  download |  icons |
# Cluster 16: | Cluster size =  23 |  sailboat |  hoominchu |  notes |  word |  functions |  die |  direct |  disney |  docs |  download |
# Cluster 17: | Cluster size =  18 |  function |  numpy |  random |  word |  für |  die |  direct |  disney |  docs |  download |
# Cluster 18: | Cluster size =  20 |  deutscher |  akademischer |  austauschdienst |  database |  scholarship |  für |  direct |  disney |  docs |  download |
# Cluster 19: | Cluster size =  18 |  school |  space |  notes |  word |  developer |  die |  direct |  disney |  docs |  download |
# Silhouette Coefficient =  0.6362717940967817
# Top terms per cluster:
# Cluster 0: | Cluster size =  3291 |  download |  microsoft |  model |  free |  datla |  algorithm |  week |  für |  profile |  overview |
# Cluster 1: | Cluster size =  15 |  tensorflow |  developer |  english |  decision |  der |  design |  detection |  deviance |  die |  disney |
# Cluster 2: | Cluster size =  14 |  vs |  islam |  free |  download |  decision |  der |  design |  detection |  developer |  deviance |
# Cluster 3: | Cluster size =  15 |  sklearn |  pipeline |  output |  random |  word |  docs |  der |  design |  detection |  developer |
# Cluster 4: | Cluster size =  19 |  studio |  na |  word |  download |  decision |  der |  design |  detection |  developer |  deviance |
# Cluster 5: | Cluster size =  17 |  functions |  sequence |  word |  download |  decision |  der |  design |  detection |  developer |  deviance |
# Cluster 6: | Cluster size =  20 |  models |  sequence |  tree |  notes |  word |  download |  decision |  der |  design |  detection |
# Cluster 7: | Cluster size =  15 |  jupyterlab |  word |  english |  decision |  der |  design |  detection |  developer |  deviance |  die |
# Cluster 8: | Cluster size =  18 |  docs |  app |  notes |  word |  english |  der |  design |  detection |  developer |  deviance |
# Cluster 9: | Cluster size =  14 |  password |  broadband |  simple |  word |  datla |  der |  design |  detection |  developer |  deviance |
# Cluster 10: | Cluster size =  14 |  random |  vs |  word |  download |  decision |  der |  design |  detection |  developer |  deviance |
# Cluster 11: | Cluster size =  15 |  singh |  random |  word |  das |  decision |  der |  design |  detection |  developer |  deviance |
# Cluster 12: | Cluster size =  20 |  column |  plot |  log |  table |  value |  check |  download |  der |  design |  detection |
# Cluster 13: | Cluster size =  13 |  iai |  word |  english |  decision |  der |  design |  detection |  developer |  deviance |  die |
# Cluster 14: | Cluster size =  16 |  icons |  design |  word |  english |  decision |  der |  detection |  developer |  deviance |  die |
# Cluster 15: | Cluster size =  22 |  19 |  covid |  english |  der |  design |  detection |  developer |  deviance |  die |  disney |
# Cluster 16: | Cluster size =  13 |  disney |  life |  english |  decision |  der |  design |  detection |  developer |  deviance |  die |
# Cluster 17: | Cluster size =  15 |  statistics |  correlation |  deviance |  residuals |  docs |  datla |  decision |  der |  design |  detection |
# Cluster 18: | Cluster size =  16 |  bootstrap |  overview |  word |  der |  design |  detection |  developer |  deviance |  die |  disney |
# Cluster 19: | Cluster size =  33 |  jobs |  intelligence |  artificial |  recipe |  2019 |  developer |  word |  download |  der |  design |
# Silhouette Coefficient =  0.6579182598958049
# Top terms per cluster:
# Cluster 0: | Cluster size =  3009 |  für |  microsoft |  die |  correlation |  study |  output |  word |  variables |  things |  datla |
# Cluster 1: | Cluster size =  14 |  audiobook |  ki |  das |  datla |  decision |  dee |  der |  detection |  developer |  deviance |
# Cluster 2: | Cluster size =  10 |  übersetzer |  download |  customer |  das |  datla |  decision |  dee |  der |  detection |  developer |
# Cluster 3: | Cluster size =  12 |  correction |  simple |  word |  algorithm |  download |  das |  datla |  decision |  dee |  der |
# Cluster 4: | Cluster size =  22 |  week |  overview |  recognition |  deviance |  coursera |  customer |  das |  datla |  decision |  dee |
# Cluster 5: | Cluster size =  16 |  profile |  detection |  plancker |  developer |  microsoft |  übersetzer |  die |  das |  datla |  decision |
# Cluster 6: | Cluster size =  11 |  coursera |  download |  customer |  das |  datla |  decision |  dee |  der |  detection |  developer |
# Cluster 7: | Cluster size =  12 |  course |  2019 |  value |  übersetzer |  die |  customer |  das |  datla |  decision |  dee |
# Cluster 8: | Cluster size =  19 |  tree |  decision |  check |  use |  output |  simple |  übersetzer |  deviance |  customer |  das |
# Cluster 9: | Cluster size =  16 |  model |  use |  simple |  übersetzer |  die |  customer |  das |  datla |  decision |  dee |
# Cluster 10: | Cluster size =  19 |  download |  free |  life |  microsoft |  vpn |  übersetzer |  deviance |  customer |  das |  datla |
# Cluster 11: | Cluster size =  16 |  algorithm |  week |  fit |  glm |  übersetzer |  die |  customer |  das |  datla |  decision |
# Cluster 12: | Cluster size =  12 |  notes |  course |  download |  customer |  das |  datla |  decision |  dee |  der |  detection |
# Cluster 13: | Cluster size =  14 |  security |  check |  übersetzer |  course |  customer |  das |  datla |  decision |  dee |  der |
# Cluster 14: | Cluster size =  13 |  college |  übersetzer |  download |  das |  datla |  decision |  dee |  der |  detection |  developer |
# Cluster 15: | Cluster size =  14 |  apple |  fiona |  übersetzer |  download |  das |  datla |  decision |  dee |  der |  detection |
# Cluster 16: | Cluster size =  12 |  louie |  things |  übersetzer |  download |  customer |  das |  datla |  decision |  dee |  der |
# Cluster 17: | Cluster size =  16 |  na |  ki |  english |  glm |  variables |  hackerrank |  deviance |  customer |  das |  datla |
# Cluster 18: | Cluster size =  19 |  deviance |  residuals |  die |  coursera |  customer |  das |  datla |  decision |  dee |  der |
# Cluster 19: | Cluster size =  15 |  uni |  tel |  aviv |  übersetzer |  customer |  das |  datla |  decision |  dee |  der |
# Silhouette Coefficient =  0.6753895296221862
# Top terms per cluster:
# Cluster 0: | Cluster size =  2773 |  die |  für |  correlation |  output |  variables |  site |  plancker |  questions |  mit |  ki |
# Cluster 1: | Cluster size =  11 |  log |  infinity |  word |  erste |  das |  datla |  dee |  der |  detection |  developer |
# Cluster 2: | Cluster size =  12 |  174 |  29 |  93 |  95 |  main |  fit |  dee |  der |  detection |  developer |
# Cluster 3: | Cluster size =  16 |  datla |  amrutha |  word |  fit |  dee |  der |  detection |  developer |  die |  english |
# Cluster 4: | Cluster size =  12 |  paradox |  infinity |  word |  erste |  das |  datla |  dee |  der |  detection |  developer |
# Cluster 5: | Cluster size =  26 |  word |  microsoft |  konto |  detection |  personal |  erste |  datla |  dee |  der |  developer |
# Cluster 6: | Cluster size =  14 |  study |  case |  recognition |  music |  word |  das |  datla |  dee |  der |  detection |
# Cluster 7: | Cluster size =  11 |  error |  vector |  word |  fiddle |  das |  datla |  dee |  der |  detection |  developer |
# Cluster 8: | Cluster size =  11 |  wolfram |  personal |  english |  fiddle |  datla |  dee |  der |  detection |  developer |  die |
# Cluster 9: | Cluster size =  15 |  tilak |  chaap |  amir |  sab |  khusrau |  chheeni |  word |  error |  datla |  dee |
# Cluster 10: | Cluster size =  9 |  fiddle |  word |  das |  datla |  dee |  der |  detection |  developer |  die |  english |
# Cluster 11: | Cluster size =  11 |  room |  bois |  locker |  case |  fiddle |  datla |  dee |  der |  detection |  developer |
# Cluster 12: | Cluster size =  11 |  hackerrank |  word |  fiddle |  das |  datla |  dee |  der |  detection |  developer |  die |
# Cluster 13: | Cluster size =  10 |  activity |  word |  fit |  datla |  dee |  der |  detection |  developer |  die |  english |
# Cluster 14: | Cluster size =  12 |  islam |  simple |  english |  free |  word |  error |  das |  datla |  dee |  der |
# Cluster 15: | Cluster size =  13 |  things |  phone |  podcast |  error |  customer |  das |  datla |  dee |  der |  detection |
# Cluster 16: | Cluster size =  9 |  museum |  word |  fiddle |  das |  datla |  dee |  der |  detection |  developer |  die |
# Cluster 17: | Cluster size =  11 |  broadband |  word |  fiddle |  datla |  dee |  der |  detection |  developer |  die |  english |
# Cluster 18: | Cluster size =  11 |  paharganj |  street |  main |  erste |  das |  datla |  dee |  der |  detection |  developer |
# Cluster 19: | Cluster size =  11 |  analysis |  word |  fit |  datla |  dee |  der |  detection |  developer |  die |  english |
# Silhouette Coefficient =  0.7173151289955046
# Top terms per cluster:
# Cluster 0: | Cluster size =  2578 |  correlation |  variables |  für |  site |  ki |  fit |  dee |  developer |  die |  use |
# Cluster 1: | Cluster size =  10 |  cloudfront |  wilder |  gene |  emirates |  english |  erste |  face |  factor |  fit |  force |
# Cluster 2: | Cluster size =  11 |  plancker |  people |  wilder |  für |  emirates |  english |  erste |  face |  factor |  fit |
# Cluster 3: | Cluster size =  8 |  quran |  für |  developer |  die |  emirates |  english |  erste |  face |  factor |  fit |
# Cluster 4: | Cluster size =  10 |  graph |  plot |  wilder |  für |  die |  emirates |  english |  erste |  face |  factor |
# Cluster 5: | Cluster size =  8 |  water |  wilder |  gene |  die |  emirates |  english |  erste |  face |  factor |  fit |
# Cluster 6: | Cluster size =  13 |  podcast |  simple |  core |  wilder |  developer |  emirates |  english |  erste |  face |  factor |
# Cluster 7: | Cluster size =  10 |  phone |  pm |  modi |  wilder |  für |  emirates |  english |  erste |  face |  factor |
# Cluster 8: | Cluster size =  11 |  vector |  value |  check |  wilder |  für |  die |  emirates |  english |  erste |  face |
# Cluster 9: | Cluster size =  11 |  vpn |  free |  wilder |  gene |  die |  emirates |  english |  erste |  face |  factor |
# Cluster 10: | Cluster size =  9 |  music |  wilder |  gene |  die |  emirates |  english |  erste |  face |  factor |  fit |
# Cluster 11: | Cluster size =  9 |  japan |  wilder |  gene |  die |  emirates |  english |  erste |  face |  factor |  fit |
# Cluster 12: | Cluster size =  10 |  2019 |  münchen |  wilder |  gene |  emirates |  english |  erste |  face |  factor |  fit |
# Cluster 13: | Cluster size =  9 |  institut |  questions |  wilder |  für |  die |  emirates |  english |  erste |  face |  factor |
# Cluster 14: | Cluster size =  10 |  wall |  journal |  street |  center |  customer |  wilder |  für |  emirates |  english |  erste |
# Cluster 15: | Cluster size =  15 |  glm |  output |  value |  wilder |  die |  emirates |  english |  erste |  face |  factor |
# Cluster 16: | Cluster size =  10 |  questions |  wilder |  für |  die |  emirates |  english |  erste |  face |  factor |  fit |
# Cluster 17: | Cluster size =  9 |  quick |  check |  für |  die |  emirates |  english |  erste |  face |  factor |  fit |
# Cluster 18: | Cluster size =  13 |  mit |  der |  die |  türkisch |  für |  wilder |  emirates |  english |  erste |  face |
# Cluster 19: | Cluster size =  9 |  page |  wilder |  die |  emirates |  english |  erste |  face |  factor |  fit |  force |
# Silhouette Coefficient =  0.7301009405693277
